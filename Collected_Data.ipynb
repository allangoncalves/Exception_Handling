# %%
import pandas as pd
import numpy as np
import csv

# %%
    url_resultado = './Documentos/repositorios.csv'
    resultado = pd.read_csv(url_resultado)
    resultado.head()
# Out:
#          id                  full_name language  stargazers_count  \
# 0    858127          pandas-dev/pandas   Python             11490
# 1   4164482              django/django   Python             29294
# 2    843222  scikit-learn/scikit-learn   Python             22528
# 3  51117837          tensorflow/models   Python             22968
# 4    596892              pallets/flask   Python             30701
#
#    forks_count  watchers_count           created_at  \
# 0         4501           11490  2010-08-24 01:37:33
# 1        12345           29294  2012-04-28 02:47:18
# 2        11917           22528  2010-08-17 09:43:38
# 3        10849           22968  2016-02-05 01:15:20
# 4         9689           30701  2010-04-06 11:11:59
#
#                                        html_url
# 0          https://github.com/pandas-dev/pandas
# 1              https://github.com/django/django
# 2  https://github.com/scikit-learn/scikit-learn
# 3          https://github.com/tensorflow/models
# ...

# %%
url = './Downloads/pandas-master/RESULTADO'
resultado = pd.read_json(url)
#para trocar linhas por colunas -> resultado = resultado.transpose()
resultado.head()
# Out:
#                      asv_bench/benchmarks/algorithms-setup  \
# except-block                                             0
# except-wo-exception                                      0
# raise                                                    0
# re-raise                                                 0
# try                                                      0
#
#                      asv_bench/benchmarks/algorithms-time_add_overflow_both_arg_nan  \
# except-block                                                         0
# except-wo-exception                                                  0
# raise                                                                0
# re-raise                                                             0
# try                                                                  0
#
#                      asv_bench/benchmarks/algorithms-time_add_overflow_first_arg_nan  \
# except-block                                                         0
# ...

# %%
url = './Downloads/models-master/RESULTADO'
resultado = pd.read_json(url)
#para trocar linhas por colunas -> resultado = resultado.transpose()
resultado.head()
# Out:
#                      official/mnist/convert_to_records-_bytes_feature  \
# except-block                                                        0
# except-wo-exception                                                 0
# raise                                                               0
# re-raise                                                            0
# try                                                                 0
#
#                      official/mnist/convert_to_records-_int64_feature  \
# except-block                                                        0
# except-wo-exception                                                 0
# raise                                                               0
# re-raise                                                            0
# try                                                                 0
#
#                      official/mnist/convert_to_records-convert_to  \
# ...

# %%
url = './Downloads/scikit-learn-master/RESULTADO'
resultado = pd.read_json(url)
#para trocar linhas por colunas -> resultado = resultado.transpose()
resultado.head()
# Out:
#                      benchmarks/bench_covertype-load_data  \
# except-block                                            0
# except-wo-exception                                     0
# raise                                                   0
# re-raise                                                0
# try                                                     0
#
#                      benchmarks/bench_glmnet-bench  \
# except-block                                     0
# except-wo-exception                              0
# raise                                            0
# re-raise                                         0
# try                                              0
#
#                      benchmarks/bench_glmnet-rmse  \
# except-block                                    0
# except-wo-exception                             0
# raise                                           0
# re-raise                                        0
# ...

# %%
url = './Downloads/youtube-dl/RESULTADO'
resultado = pd.read_json(url)
#para trocar linhas por colunas -> resultado = resultado.transpose()
resultado.head()
# Out:
#                      devscripts/bash-completion-build_completion  \
# except-block                                                   0
# except-wo-exception                                            0
# raise                                                          0
# re-raise                                                       0
# try                                                            0
#
#                      devscripts/buildserver-__init__  \
# except-block                                       0
# except-wo-exception                                0
# raise                                              0
# re-raise                                           0
# try                                                0
#
#                      devscripts/buildserver-__str__  \
# except-block                                      0
# except-wo-exception                               0
# raise                                             0
# ...
