# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import csv

# %% [markdown]
# ### Repositories

# %%
    url_resultado = 'repositorios.csv'
    resultado = pd.read_csv(url_resultado)
    resultado.head()
# Out:
#          id                  full_name language  stargazers_count  \
# 0    858127          pandas-dev/pandas   Python             11490
# 1   4164482              django/django   Python             29294
# 2    843222  scikit-learn/scikit-learn   Python             22528
# 3  51117837          tensorflow/models   Python             22968
# 4    596892              pallets/flask   Python             30701
#
#    forks_count  watchers_count           created_at  \
# 0         4501           11490  2010-08-24 01:37:33
# 1        12345           29294  2012-04-28 02:47:18
# 2        11917           22528  2010-08-17 09:43:38
# 3        10849           22968  2016-02-05 01:15:20
# 4         9689           30701  2010-04-06 11:11:59
#
#                                        html_url
# 0          https://github.com/pandas-dev/pandas
# 1              https://github.com/django/django
# 2  https://github.com/scikit-learn/scikit-learn
# 3          https://github.com/tensorflow/models
# ...

# %% [markdown]
# ### Reading the file

# %%
url = 'pandas-master/RESULTADO.json'
df = pd.read_json(url).transpose()

# %% [markdown]
# ### Sorting and showing the data

# %%
df.sort_values(by=['except-block'], ascending=False, inplace=True)
#df['except_blocks_size']
df.head()
# Out:
#                                            except-block  \
# pandas/core/tools/datetimes-to_datetime               9
# pandas/core/indexes/multi-get_value                   9
# pandas/core/indexes/base-__new__                      6
# pandas/core/base-_aggregate_multiple_funcs            6
# pandas/core/indexes/base-get_value                    6
#
#                                                      except_blocks_size  \
# pandas/core/tools/datetimes-to_datetime     [1, 1, 2, 2, 3, 1, 1, 1, 1]
# pandas/core/indexes/multi-get_value         [7, 1, 1, 2, 1, 6, 1, 1, 1]
# pandas/core/indexes/base-__new__                     [1, 2, 1, 1, 1, 1]
# pandas/core/base-_aggregate_multiple_funcs           [1, 1, 1, 0, 1, 3]
# pandas/core/indexes/base-get_value                   [1, 6, 1, 2, 1, 2]
#
#                                            exception_tuples_size  \
# pandas/core/tools/datetimes-to_datetime                      [2]
# ...
